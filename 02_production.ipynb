# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# # From Model to Production

# %% [markdown]
# ## The Practice of Deep Learning

# %% [markdown]
# ### Starting Your Project

# %% [markdown]
# ### The State of Deep Learning

# %% [markdown]
# #### Computer vision

# %% [markdown]
# #### Text (natural language processing)

# %% [markdown]
# #### Combining text and images

# %% [markdown]
# #### Tabular data

# %% [markdown]
# #### Recommendation systems

# %% [markdown]
# #### Other data types

# %% [markdown]
# ### The Drivetrain Approach

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# # clean
# To download images with Bing Image Search, sign up at [Microsoft Azure](https://azure.microsoft.com/en-us/services/cognitive-services/bing-web-search-api/) for a free account. You will be given a key, which you can copy and enter in a cell as follows (replacing 'XXX' with your key and executing it):

# %%
# !pip install -q jmd_imagescraper

# %%
from jmd_imagescraper.core import * 
from pathlib import Path
from jmd_imagescraper.imagecleaner import *

# %%
bears=['grizzly','black','teddy']
path = Path().cwd()/"bears"#assigns path to current working directory

# %%
duckduckgo_search(path,"grizzly","grizzly bears",max_results=100) #downloads 100 images of 'cats' and saves it in path/cat
duckduckgo_search(path,"black","black bears",max_results=100) #downloads 100 images of 'cats' and saves it in path/cat
duckduckgo_search(path,"teddy","teddy bears",max_results=100) #downloads 100 images of 'cats' and saves it in path/cat
# Out:
# Duckduckgo search: grizzly bears
# Downloading results into /notebooks/clean/bears/grizzly
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:12<00:00 Images downloaded]
#     </div>
# Duckduckgo search: black bears
# Downloading results into /notebooks/clean/bears/black
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:17<00:00 Images downloaded]
#     </div>
# Duckduckgo search: teddy bears
# Downloading results into /notebooks/clean/bears/teddy
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:16<00:00 Images downloaded]
#     </div>
# [Path('/notebooks/clean/bears/teddy/001_ea20d4fe.jpg'),
#  Path('/notebooks/clean/bears/teddy/002_65ed0c0f.jpg'),
#  Path('/notebooks/clean/bears/teddy/003_cb604fbd.jpg'),
#  Path('/notebooks/clean/bears/teddy/004_7eee0242.jpg'),
#  Path('/notebooks/clean/bears/teddy/005_ba8b17ac.jpg'),
#  Path('/notebooks/clean/bears/teddy/006_3f0397d1.jpg'),
#  Path('/notebooks/clean/bears/teddy/007_32e6c607.jpg'),
#  Path('/notebooks/clean/bears/teddy/008_13ef7dde.jpg'),
#  Path('/notebooks/clean/bears/teddy/009_4a4021f2.jpg'),
#  Path('/notebooks/clean/bears/teddy/010_3304f76e.jpg'),
#  Path('/notebooks/clean/bears/teddy/011_3038290a.jpg'),
#  Path('/notebooks/clean/bears/teddy/012_4a63a145.jpg'),
#  Path('/notebooks/clean/bears/teddy/013_d1822274.jpg'),
#  Path('/notebooks/clean/bears/teddy/014_2210430d.jpg'),
#  Path('/notebooks/clean/bears/teddy/015_0d2b2250.jpg'),
#  Path('/notebooks/clean/bears/teddy/016_1d2aa4a4.jpg'),
#  Path('/notebooks/clean/bears/teddy/017_98558bf5.jpg'),
#  Path('/notebooks/clean/bears/teddy/018_2f36171d.jpg'),
#  Path('/notebooks/clean/bears/teddy/019_e5a00061.jpg'),
#  Path('/notebooks/clean/bears/teddy/020_b0ce7487.jpg'),
#  Path('/notebooks/clean/bears/teddy/021_302d8b35.jpg'),
#  Path('/notebooks/clean/bears/teddy/022_19a20322.jpg'),
#  Path('/notebooks/clean/bears/teddy/023_749337ed.jpg'),
#  Path('/notebooks/clean/bears/teddy/024_21d9d622.jpg'),
#  Path('/notebooks/clean/bears/teddy/025_776a5263.jpg'),
#  Path('/notebooks/clean/bears/teddy/026_1fd1aa8d.jpg'),
#  Path('/notebooks/clean/bears/teddy/027_96866ea0.jpg'),
#  Path('/notebooks/clean/bears/teddy/028_dae1c7bd.jpg'),
#  Path('/notebooks/clean/bears/teddy/029_e2ad8457.jpg'),
#  Path('/notebooks/clean/bears/teddy/030_c5c399d6.jpg'),
#  Path('/notebooks/clean/bears/teddy/031_8e1151c2.jpg'),
#  Path('/notebooks/clean/bears/teddy/032_c61f2f8f.jpg'),
#  Path('/notebooks/clean/bears/teddy/033_e72f7511.jpg'),
#  Path('/notebooks/clean/bears/teddy/034_5781892f.jpg'),
#  Path('/notebooks/clean/bears/teddy/035_3e90c038.jpg'),
#  Path('/notebooks/clean/bears/teddy/036_ef6266ab.jpg'),
#  Path('/notebooks/clean/bears/teddy/037_d5d8064c.jpg'),
#  Path('/notebooks/clean/bears/teddy/038_30a138fc.jpg'),
#  Path('/notebooks/clean/bears/teddy/039_cedb0d08.jpg'),
#  Path('/notebooks/clean/bears/teddy/040_93bf1169.jpg'),
#  Path('/notebooks/clean/bears/teddy/041_06d86639.jpg'),
#  Path('/notebooks/clean/bears/teddy/042_fc3f59df.jpg'),
#  Path('/notebooks/clean/bears/teddy/043_df978230.jpg'),
#  Path('/notebooks/clean/bears/teddy/044_5305f17c.jpg'),
#  Path('/notebooks/clean/bears/teddy/045_7fb618b1.jpg'),
#  Path('/notebooks/clean/bears/teddy/046_3d3f593c.jpg'),
#  Path('/notebooks/clean/bears/teddy/047_0fb961f3.jpg'),
#  Path('/notebooks/clean/bears/teddy/048_2540cca6.jpg'),
#  Path('/notebooks/clean/bears/teddy/049_f065b638.jpg'),
#  Path('/notebooks/clean/bears/teddy/050_e9a9a98d.jpg'),
#  Path('/notebooks/clean/bears/teddy/051_8a86273d.jpg'),
#  Path('/notebooks/clean/bears/teddy/052_6060068e.jpg'),
#  Path('/notebooks/clean/bears/teddy/053_f163476c.jpg'),
#  Path('/notebooks/clean/bears/teddy/054_6caaee6b.jpg'),
#  Path('/notebooks/clean/bears/teddy/055_7415aa50.jpg'),
#  Path('/notebooks/clean/bears/teddy/056_be7ee7c9.jpg'),
#  Path('/notebooks/clean/bears/teddy/057_6e3807aa.jpg'),
#  Path('/notebooks/clean/bears/teddy/058_d670bc95.jpg'),
#  Path('/notebooks/clean/bears/teddy/059_5e98b958.jpg'),
#  Path('/notebooks/clean/bears/teddy/060_f9021ab9.jpg'),
#  Path('/notebooks/clean/bears/teddy/061_03192338.jpg'),
#  Path('/notebooks/clean/bears/teddy/062_179f01b9.jpg'),
#  Path('/notebooks/clean/bears/teddy/063_e22e49d9.jpg'),
#  Path('/notebooks/clean/bears/teddy/064_b529f07b.jpg'),
#  Path('/notebooks/clean/bears/teddy/065_14161fd2.jpg'),
#  Path('/notebooks/clean/bears/teddy/066_cda60086.jpg'),
#  Path('/notebooks/clean/bears/teddy/067_80d77370.jpg'),
#  Path('/notebooks/clean/bears/teddy/068_ead0312e.jpg'),
#  Path('/notebooks/clean/bears/teddy/069_b793d5c6.jpg'),
#  Path('/notebooks/clean/bears/teddy/070_2763324d.jpg'),
#  Path('/notebooks/clean/bears/teddy/071_f0033a40.jpg'),
#  Path('/notebooks/clean/bears/teddy/072_c97544cc.jpg'),
#  Path('/notebooks/clean/bears/teddy/073_ac09d3b6.jpg'),
#  Path('/notebooks/clean/bears/teddy/074_bf0216bc.jpg'),
#  Path('/notebooks/clean/bears/teddy/075_91710b89.jpg'),
#  Path('/notebooks/clean/bears/teddy/076_9e93f2d0.jpg'),
#  Path('/notebooks/clean/bears/teddy/077_92a51932.jpg'),
#  Path('/notebooks/clean/bears/teddy/078_9ee00657.jpg'),
#  Path('/notebooks/clean/bears/teddy/079_e5718da1.jpg'),
#  Path('/notebooks/clean/bears/teddy/080_66a1cb32.jpg'),
#  Path('/notebooks/clean/bears/teddy/081_e226f6c8.jpg'),
#  Path('/notebooks/clean/bears/teddy/082_c272a0a8.jpg'),
#  Path('/notebooks/clean/bears/teddy/083_c9baa7bc.jpg'),
#  Path('/notebooks/clean/bears/teddy/084_1e094f74.jpg'),
#  Path('/notebooks/clean/bears/teddy/085_eb07d903.jpg'),
#  Path('/notebooks/clean/bears/teddy/086_30e13108.jpg'),
#  Path('/notebooks/clean/bears/teddy/087_36a4855a.jpg'),
#  Path('/notebooks/clean/bears/teddy/088_eb443c14.jpg'),
#  Path('/notebooks/clean/bears/teddy/089_0cddbb84.jpg'),
#  Path('/notebooks/clean/bears/teddy/090_23b1010d.jpg'),
#  Path('/notebooks/clean/bears/teddy/091_14ffa671.jpg'),
#  Path('/notebooks/clean/bears/teddy/092_c87570f1.jpg'),
#  Path('/notebooks/clean/bears/teddy/093_9f7b752b.jpg'),
#  Path('/notebooks/clean/bears/teddy/094_40ae533b.jpg'),
#  Path('/notebooks/clean/bears/teddy/095_4e8c2b23.jpg'),
#  Path('/notebooks/clean/bears/teddy/096_b9d386d4.jpg'),
#  Path('/notebooks/clean/bears/teddy/097_dbe90c35.jpg'),
#  Path('/notebooks/clean/bears/teddy/098_83cda689.jpg'),
#  Path('/notebooks/clean/bears/teddy/099_29803af4.jpg'),
#  Path('/notebooks/clean/bears/teddy/100_c81fbf4c.jpg')]

# %%
display_image_cleaner(path)
# Out:
# HBox(children=(Button(description='|<<', layout=Layout(width='60px'), style=ButtonStyle()), Button(description…
# HTML(value='<h2>No images left to display in this folder.</h2>', layout=Layout(visibility='hidden'))
# GridBox(children=(VBox(children=(Image(value=b'', layout="Layout(width='150px')"), Button(description='Delete'…

# %%
urls = search_images_ddg('grizzly bear', max_images=100)
#len(urls),urls[0]

# %%
key = os.environ.get('AZURE_SEARCH_KEY', 'XXX')

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing(key, term, min_sz=128, max_images=150)>

# %%
results = search_images_bing(key, 'grizzly bear')
ims = results.attrgot('content_url')
len(ims)

# %%
#hide
ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
dest = 'images/grizzly.jpg'
download_url(ims[0], dest)

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=108x128 at 0x7F2AC0E69EB0>

# %%
bear_types = 'grizzly','black','teddy'
path = Path('bears')

# %%
if not path.exists():
    path.mkdir()
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = duckduckgo_search(dest, f'{o} bear', f'{o} bear', max_results=100)
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#700) [Path('/notebooks/clean/bears/grizzly/075_73cc6da1.jpg'),Path('/notebooks/clean/bears/grizzly/086_c5196080.jpg'),Path('/notebooks/clean/bears/grizzly/044_a9ccfa57.jpg'),Path('/notebooks/clean/bears/grizzly/023_e1ed0c3c.jpg'),Path('/notebooks/clean/bears/grizzly/058_b3c6c862.jpg'),Path('/notebooks/clean/bears/grizzly/061_59ce8be6.jpg'),Path('/notebooks/clean/bears/grizzly/011_f9a96b9b.jpg'),Path('/notebooks/clean/bears/grizzly/078_cbc63bb0.jpg'),Path('/notebooks/clean/bears/grizzly/020_03578c6d.jpg'),Path('/notebooks/clean/bears/grizzly/090_1377a6b5.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
failed.map(Path.unlink);

# %% [markdown]
# ### Sidebar: Getting Help in Jupyter Notebooks

# %% [markdown]
# ### End sidebar

# %% [markdown]
# ## From Data to DataLoaders

# %%
#duckduckgo_search(path2,"black","black bears",max_results=100)

bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = bears.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %% [markdown]
# ### Data Augmentation

# %%
bears = bears.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
bears = bears.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = bears.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.193807</td>
#       <td>0.816842</td>
#       <td>0.290000</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.156659</td>
#       <td>1.148765</td>
#       <td>0.420000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.143609</td>
#       <td>1.457517</td>
#       <td>0.460000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.109876</td>
#       <td>1.525481</td>
#       <td>0.490000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.086270</td>
#       <td>1.371407</td>
#       <td>0.460000</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=5)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# VBox(children=(Dropdown(options=('black', 'grizzly', 'grizzly bear', 'teddy'), value='black'), Dropdown(option…

# %%
#hide
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# ### Using the Model for Inference

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/grizzly.jpg')
# Out:
# ('grizzly', tensor(1), tensor([0.0048, 0.9721, 0.0231]))

# %%
learn_inf.dls.vocab
# Out:
# ['black', 'grizzly', 'teddy']

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/grizzly.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: grizzly; Probability: 0.9721')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bear!'), FileUpload(value={}, description='Upload'), Button(descriptio…

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Downloading voila-0.2.7-py3-none-any.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 15.5 MB/s eta 0:00:01
# Collecting nbconvert<7,>=6.0.0
#   Downloading nbconvert-6.0.7-py3-none-any.whl (552 kB)
#      |████████████████████████████████| 552 kB 71.2 MB/s eta 0:00:01
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from voila) (0.5.1)
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from voila) (6.1.7)
# Collecting jupyter-server<2.0.0,>=0.3.0
#   Downloading jupyter_server-1.4.1-py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 47.3 MB/s eta 0:00:01
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (2.7.2)
# Requirement already satisfied: jupyter-core in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (4.7.0)
# Requirement already satisfied: defusedxml in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.1.2)
# Requirement already satisfied: testpath in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.4.4)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (5.0.5)
# Requirement already satisfied: bleach in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (3.2.1)
# Requirement already satisfied: jinja2>=2.4 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (2.11.2)
# Requirement already satisfied: nbformat>=4.4 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (5.0.8)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.4.3)
# Requirement already satisfied: async-generator in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (20.0.0)
# Requirement already satisfied: tornado>=4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: ipython-genutils in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: Send2Trash in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.1)
# Requirement already satisfied: prometheus-client in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.0)
# Collecting anyio>=2.0.2
#   Downloading anyio-2.2.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 8.6 MB/s  eta 0:00:01
# Requirement already satisfied: webencodings in /opt/conda/envs/fastai/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: packaging in /opt/conda/envs/fastai/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (20.4)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jinja2>=2.4->nbconvert<7,>=6.0.0->voila) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (3.2.0)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /opt/conda/envs/fastai/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila) (0.6.0)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from anyio>=2.0.2->jupyter-server<2.0.0,>=0.3.0->voila) (2.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# Requirement already satisfied: setuptools in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (49.6.0.post20201009)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (20.3.0)
# Installing collected packages: nbconvert, sniffio, anyio, jupyter-server, voila
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# nbdev 1.1.5 requires nbconvert<6, but you'll have nbconvert 6.0.7 which is incompatible.
# Successfully installed anyio-2.2.0 jupyter-server-1.4.1 nbconvert-6.0.7 sniffio-1.2.0 voila-0.2.7
# Enabling: voila
# - Writing config: /opt/conda/envs/fastai/etc/jupyter
#     - Validating...
#       voila 0.2.7 OK

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# ## How to Avoid Disaster

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.
# 1. Where do text models currently have a major deficiency?
# 1. What are possible negative societal implications of text generation models?
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
# 1. What kind of tabular data is deep learning particularly good at?
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
# 1. What are the steps of the Drivetrain Approach?
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
# 1. Create an image recognition model using data you curate, and deploy it on the web.
# 1. What is `DataLoaders`?
# 1. What four things do we need to tell fastai to create `DataLoaders`?
# 1. What does the `splitter` parameter to `DataBlock` do?
# 1. How do we ensure a random split always gives the same validation set?
# 1. What letters are often used to signify the independent and dependent variables?
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
# 1. What is data augmentation? Why is it needed?
# 1. What is the difference between `item_tfms` and `batch_tfms`?
# 1. What is a confusion matrix?
# 1. What does `export` save?
# 1. What is it called when we use a model for getting predictions, instead of training?
# 1. What are IPython widgets?
# 1. When might you want to use CPU for deployment? When might GPU be better?
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
# 1. What is "out-of-domain data"?
# 1. What is "domain shift"?
# 1. What are the three steps in the deployment process?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
